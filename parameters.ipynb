# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
kidpan_data = pd.read_csv(
    "C:/Users/brand/Desktop/STAR_Delimited/Delimited Text File 202312/Kidney_ Pancreas_ Kidney-Pancreas/KIDPAN_DATA.DAT",
    sep="\t"
)
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_6260\312378857.py:1: DtypeWarning: Columns (2,5,8,10,11,12,13,17,18,19,20,21,22,23,27,28,29,30,31,33,34,35,37,38,44,45,46,47,48,51,52,53,54,65,66,67,69,70,71,72,73,74,75,76,77,78,81,82,83,84,85,86,87,88,89,90,91,92,93,99,103,104,105,106,107,108,111,112,114,115,116,117,119,121,122,131,133,134,135,136,137,138,139,140,148,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,198,199,201,202,203,204,205,206,207,208,209,210,211,212,213,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,233,234,235,236,237,238,239,240,241,242,243,245,246,247,249,250,251,252,254,255,256,257,258,259,260,261,262,263,267,268,269,270,276,278,279,280,281,284,286,288,289,293,294,295,296,297,298,299,300,301,302,305,307,308,309,313,314,316,320,327,329,331,332,334,335,336,337,338,339,340,341,342,343,346,347,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,370,371,372,376,377,378,379,380,381,382,383,385,386,387,388,389,390,392,408,409,410,411,412,413,414,417,418,419,421,422,428,429,430,431,432,433,434,435,436,437,438,439,442,443,445,446,447,449,454,455,456,457,458,459,467,468,469,470,471) have mixed types. Specify dtype option on import or set low_memory=False.
#   kidpan_data = pd.read_csv(

# %%
colnames = pd.read_csv(
    "C:/Users/brand/Desktop/STAR_Delimited/Analysis/KIDPAN_DATA_colnames.csv",
    sep=",",
    header=0
)

# %%
kidpan_data.columns = list(colnames["LABEL"])

# %%
kidpan_data = kidpan_data[kidpan_data["WL_ORG"] == "KI"]
kidpan_data.shape
# Out:
# (1051867, 472)

# %%
ages = kidpan_data["INIT_AGE"].replace(".", np.nan).astype(float)
ax = ages.hist(bins=np.arange(0,np.max(ages)+10,10))
ax.set_xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')
